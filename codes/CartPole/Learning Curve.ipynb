# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
DQN = np.load('curve\DQN.npy')
DAQN = np.load('curve\DAQN.npy')
DATQN = np.load('curve\DATQN.npy')

# %%
plt.plot(DQN)
plt.plot(DAQN)
plt.plot(DATQN)
plt.xlabel("episode")
plt.ylabel("average mean of last ")
plt.xlim(-250,2200)
plt.title("Comparison of 3 Different Method")
plt.legend(["DQN","DAQN","DATQN"],loc='upper left',ncol=1)
